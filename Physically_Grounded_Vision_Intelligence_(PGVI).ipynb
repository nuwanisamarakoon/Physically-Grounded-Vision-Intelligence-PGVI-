# %% [markdown]
# <a href="https://colab.research.google.com/github/nuwanisamarakoon/Physically-Grounded-Vision-Intelligence-PGVI-/blob/main/Physically_Grounded_Vision_Intelligence_(PGVI).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics opencv-python matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 34.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load pretrained YOLOv8 model
model = YOLO("yolov8x.pt")   # lightweight version (you can use yolov8m.pt for better accuracy)

# Load image
image_path = "ball and table.jpeg"
image = cv2.imread(image_path)

# Run detection
results = model(image)

# Draw results
annotated_image = results[0].plot()

# Convert BGR → RGB for displaying
annotated_image = cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB)

# Show image
plt.imshow(annotated_image)
plt.axis("off")
plt.show()
# Out:
# 0: 448x640 1 sports ball, 1 book, 69.9ms
# Speed: 1.6ms preprocess, 69.9ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
